# %%
from multiplot import feature_plot

import pickle
import os

import matplotlib.pyplot as plt
# %matplotlib inline

font = {'weight' : 'bold',
        'size'   : 18}

import matplotlib
matplotlib.rc('font', **font)

cols = ['#000000','#e41a1c','#377eb8','#4daf4a','#984ea3','#ff7f00','#a65628','#f781bf']

# %% [markdown]
# ## NNZ

# %%
f_nnz = open('../../data/graphs/desikan_nnz.pkl')

nnz = pickle.load(f_nnz)['nnz']
f_nnz.close()
dnames = nnz.keys()

plt_nnz = feature_plot(nnz, dnames, 'Number of Non-zero Edges (Desikan Atlas)', plot_mode='scatter',
                       fig_outfile='../../figs/graphs/desikan/multi_nnz_desikan_scatter_colourful.png', color=cols)

# %% [markdown]
# ## Degree Distribution

# %%
f_deg = open('../../data/graphs/desikan_degree.pkl')

degree = pickle.load(f_deg)['degree']
f_deg.close()
dnames = degree.keys()

plt_nnz = feature_plot(degree, dnames, 'Degree Distribution (Desikan Atlas)', plot_mode='hist', xlims = [0, 70],
                       ylab='Density', xlab= 'Vertex Degree', color=cols,
                       fig_outfile='../../figs/graphs/desikan/multi_degree_desikan_hist_colourful.png')

# %% [markdown]
# ## Edge Weight Sequence

# %%
f_ew = open('../../data/graphs/desikan_edgeweight.pkl')

ew = pickle.load(f_ew)['edgeweight']
f_ew.close()
dnames = ew.keys()

plt_nnz = feature_plot(ew, dnames, 'Edge Weight Distribution (Desikan Atlas)', plot_mode='hist', axis_scale='log', yscale=1000,
                       ylab='Density (E-3)', xlab='Edge Weight', fig_outfile='../../figs/graphs/desikan/multi_ew_desikan_hist.png')

# %% [markdown]
# ## Clustering Coefficient Distribution

# %%
f_cc = open('../../data/graphs/desikan_ccoefs.pkl')

cc = pickle.load(f_cc)['ccoefs']
f_cc.close()
dnames = cc.keys()

plt_nnz = feature_plot(cc, dnames, 'Clustering Coefficient Distribution (Desikan Atlas)', plot_mode='hist',
                       ylab='Density', xlab='Clustering Coefficient', fig_outfile='../../figs/graphs/desikan/multi_cc_desikan_hist.png')

# %% [markdown]
# ## Scan Statistic-1 Distribution

# %%
f_ss1 = open('../../data/graphs/desikan_ss1.pkl')

ss1 = pickle.load(f_ss1)['ss1']
f_ss1.close()
dnames = ss1.keys()

plt_nnz = feature_plot(ss1, dnames, 'Scan Statistic-1 Distribution (Desikan Atlas)', plot_mode='hist', axis_scale='log',
                       yscale=1000000, ylab='Density (E-6)', xlab='Scan Statistic-1',
                       fig_outfile='../../figs/graphs/desikan/multi_ss1_desikan_hist.png')

# %% [markdown]
# ## Eigen Value Sequence

# %%
f_eig = open('../../data/graphs/desikan_eigs.pkl')

eig = pickle.load(f_eig)['eigs']
f_eig.close()
dnames = eig.keys()

plt_nnz = feature_plot(eig, dnames, 'Eigen Value Seuqnce (Desikan Atlas)', plot_mode='series',
                       ylab='Value', xlab='Dimension (100)', fig_outfile='../../figs/graphs/desikan/multi_eig_desikan_hist.png')

# %% [markdown]
# ## Betweenness Centrality Distribution

# %%
f_bc = open('../../data/graphs/desikan_centrality.pkl')

bc = pickle.load(f_bc)['centrality']
f_bc.close()
dnames = bc.keys()

plt_nnz = feature_plot(bc, dnames, 'Betweenness Centrality (Desikan Atlas)', plot_mode='hist', axis_scale='log',
                       ylab='Density', xlab='Value', fig_outfile='../../figs/graphs/desikan/multi_bc_desikan_hist.png')
