# %%
from multiplot import feature_plot

import pickle
import os

import matplotlib.pyplot as plt
# %matplotlib inline

font = {'weight' : 'bold',
        'size'   : 14}

import matplotlib
matplotlib.rc('font', **font)

# %% [markdown]
# ## NNZ

# %%
f_nnz = open('../../data/graphs/cpac200_nnz.pkl')

nnz = pickle.load(f_nnz)['nnz']
f_nnz.close()
dnames = nnz.keys()

plt_nnz = feature_plot(nnz, dnames, 'Number of Non-zero Edges (CPAC200 Atlas)', plot_mode='scatter',
                       fig_outfile='../../figs/graphs/cpac200/multi_nnz_cpac200_scatter.png')

# %% [markdown]
# ## Degree Distribution

# %%
f_deg = open('../../data/graphs/cpac200_degree.pkl')

degree = pickle.load(f_deg)['degree']
f_deg.close()
dnames = degree.keys()

plt_nnz = feature_plot(degree, dnames, 'Degree Distribution (CPAC200 Atlas)', plot_mode='hist', xlims = [0, 200],
                       ylab='Density', xlab= 'Vertex Degree', fig_outfile='../../figs/graphs/cpac200/multi_degree_cpac200_hist.png')

# %% [markdown]
# ## Edge Weight Sequence

# %%
f_ew = open('../../data/graphs/cpac200_edgeweight.pkl')

ew = pickle.load(f_ew)['edgeweight']
f_ew.close()
dnames = ew.keys()

plt_nnz = feature_plot(ew, dnames, 'Edge Weight Distribution (CPAC200 Atlas)', plot_mode='hist', axis_scale='log', yscale=1000,
                       ylab='Density (E-3)', xlab='Edge Weight', fig_outfile='../../figs/graphs/cpac200/multi_ew_cpac200_hist.png')

# %% [markdown]
# ## Clustering Coefficient Distribution

# %%
f_cc = open('../../data/graphs/cpac200_ccoefs.pkl')

cc = pickle.load(f_cc)['ccoefs']
f_cc.close()
dnames = cc.keys()

plt_nnz = feature_plot(cc, dnames, 'Clustering Coefficient Distribution (CPAC200 Atlas)', plot_mode='hist',
                       ylab='Density', xlab='Clustering Coefficient', fig_outfile='../../figs/graphs/cpac200/multi_cc_cpac200_hist.png')

# %% [markdown]
# ## Scan Statistic-1 Distribution

# %%
f_ss1 = open('../../data/graphs/cpac200_ss1.pkl')

ss1 = pickle.load(f_ss1)['ss1']
f_ss1.close()
dnames = ss1.keys()

plt_nnz = feature_plot(ss1, dnames, 'Scan Statistic-1 Distribution (CPAC200 Atlas)', plot_mode='hist', axis_scale='log',
                       yscale=1000000, ylab='Density (E-6)', xlab='Scan Statistic-1',
                       fig_outfile='../../figs/graphs/cpac200/multi_ss1_cpac200_hist.png')

# %% [markdown]
# ## Eigen Value Sequence

# %%
f_eig = open('../../data/graphs/cpac200_eigs.pkl')

eig = pickle.load(f_eig)['eigs']
f_eig.close()
dnames = eig.keys()

plt_nnz = feature_plot(eig, dnames, 'Eigen Value Seuqnce (CPAC200 Atlas)', plot_mode='series', xscale=1,
                       ylab='Value', xlab='Dimension', fig_outfile='../../figs/graphs/cpac200/multi_eig_cpac200_hist.png')

# %% [markdown]
# ## Betweenness Centrality Distribution

# %%
f_bc = open('../../data/graphs/cpac200_centrality.pkl')

bc = pickle.load(f_bc)['centrality']
f_bc.close()
dnames = bc.keys()

plt_nnz = feature_plot(bc, dnames, 'Betweenness Centrality (CPAC200 Atlas)', plot_mode='hist', axis_scale='log',
                       ylab='Density', xlab='Value', fig_outfile='../../figs/graphs/cpac200/multi_bc_cpac200_hist.png')
