# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np
import nibabel as nb
import os

from multiplot import hist_plot

font = {'weight' : 'bold',
        'size'   : 14}

import matplotlib
matplotlib.rc('font', **font)

# %%
"""
8
"""
files = list(('./data/KKI2009_b0_pdfs.pkl', './data/BNU1_b0_pdfs.pkl',
             './data/BNU3_b0_pdfs.pkl', './data/NKI1_b0_pdfs.pkl',
              './data/NKIENH_b0_pdfs.pkl', './data/MRN114_b0_pdfs.pkl',
             './data/MRN1313_b0_pdfs.pkl', './data/SWU4_b0_pdfs.pkl'))
names = list(('KKI2009', 'BNU1', 'BNU3', 'NKI1', 'NKIENH', 'MRN114', 'MRN1313', 'SWU4'))

# %%
hist_plot(files, names, figname='./ndmg_fig3.png')
# Out:
# ['KKI2009', 'BNU1', 'BNU3', 'NKI1', 'NKIENH', 'MRN114', 'MRN1313', 'SWU4']
# [2, 4]
# <multiplot.hist_plot instance at 0x10b4ca7a0>

# %%
"""
9
"""
files = list(('./data/KKI2009_b0_pdfs.pkl', './data/BNU1_b0_pdfs.pkl',
             './data/BNU3_b0_pdfs.pkl', './data/NKI1_b0_pdfs.pkl',
              './data/NKIENH_b0_pdfs.pkl', './data/MRN114_b0_pdfs.pkl',
             './data/MRN1313_b0_pdfs.pkl', './data/SWU4_b0_pdfs.pkl','./data/KKI2009_b0_pdfs.pkl'))
names = list(('KKI2009', 'BNU1', 'BNU3', 'NKI1', 'NKIENH', 'MRN114', 'MRN1313', 'SWU4', 'KKI20092'))

# %%
hist_plot(files, names)
# Out:
# ['KKI2009', 'BNU1', 'BNU3', 'NKI1', 'NKIENH', 'MRN114', 'MRN1313', 'SWU4', 'KKI20092']
# <multiplot.hist_plot instance at 0x114e54d40>

# %%
"""
11
"""
files = list(('./data/KKI2009_b0_pdfs.pkl', './data/BNU1_b0_pdfs.pkl',
              './data/BNU3_b0_pdfs.pkl', './data/NKI1_b0_pdfs.pkl',
              './data/NKIENH_b0_pdfs.pkl', './data/MRN114_b0_pdfs.pkl',
              './data/MRN1313_b0_pdfs.pkl', './data/SWU4_b0_pdfs.pkl',
              './data/KKI2009_b0_pdfs.pkl', './data/BNU1_b0_pdfs.pkl',
              './data/KKI2009_b0_pdfs.pkl'))
names = list(('KKI2009', 'BNU1', 'BNU3', 'NKI1', 'NKIENH', 'MRN114',
              'MRN1313', 'SWU4', 'KKI2009-2',  'BNU1-2', 'KKI2009-3'))

# %%
hist_plot(files, names)
# Out:
# ['KKI2009', 'BNU1', 'BNU3', 'NKI1', 'NKIENH', 'MRN114', 'MRN1313', 'SWU4', 'KKI2009-2', 'BNU1-2', 'KKI2009-3']
# []
# [2, 3, 4, 6]
# <multiplot.hist_plot instance at 0x1169b3830>
